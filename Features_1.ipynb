# %%
import pandas as pd
orders = pd.read_parquet("orders.parquet")  
order_products_denormalized = pd.read_csv("order_products_denormalized.csv")  
tips_public = pd.read_csv("tips_public.csv").drop(columns=["Unnamed: 0"])

# %%
orders.head(1)
# Out:
#    order_id  user_id          order_date
# 0   1374495        3 2024-03-31 14:05:18

# %%
tips_public.head(1)
# Out:
#    order_id   tip
# 0   1374495  True

# %%
order_products_denormalized_sample = order_products_denormalized[order_products_denormalized["order_id"] < 10000]
order_products_denormalized.tail(1)
# Out:
#           order_id  product_id  add_to_cart_order  \
# 14857352   3421083        5020                 10
#
#                                                product_name  aisle_id  \
# 14857352  Organic  Sweet & Salty Peanut Pretzel Granola ...         3
#
#           department_id department                aisle
# 14857352             19     snacks  energy granola bars

# %% [markdown]
# ### Feature engineering **USER**: new table per feature with columns: user_id, feature_name

# %%
def add_feature_alcohol_count():
    # 1. Filter products in the "alcohol" department
    alcohol_df = order_products_denormalized[order_products_denormalized["department"] == "alcohol"]

    # 2. Join with the 'orders' table to get user_id for each order
    alcohol_with_users = alcohol_df.merge(orders[["order_id", "user_id"]], on="order_id")

    # 3. Count how many times each user bought alcohol
    alcohol_counts = alcohol_with_users["user_id"].value_counts().reset_index()
    alcohol_counts.columns = ["user_id", "alcohol_purchases"]

    # Optional: sort users by alcohol purchases (descending)
    alcohol_counts = alcohol_counts.sort_values(by="alcohol_purchases", ascending=False)

    # 4. Merge with all user_ids to include users with 0 alcohol purchases
    result = (
        alcohol_counts
        .merge(orders[["user_id"]], how="right")
        .drop_duplicates()
        .fillna(0)
        .set_index("user_id")
    )

    return result
   
#add_feature_alcohol_count().head(1)

# %%
def total_products_per_user():
    # Join order_products_denormalized mit orders, um user_id zu bekommen
    merged = order_products_denormalized.merge(orders[["order_id", "user_id"]], on="order_id")
    
    # Für jeden user_id die Gesamtanzahl der Produkte zählen (inkl. Duplikate)
    total_products = merged.groupby("user_id")["product_id"].count().reset_index()
    total_products.columns = ["user_id", "total_products_bought"]
    
    return total_products
#total_products_per_user().head(1)
# Out:
#    user_id  total_products_bought
# 0        3                     88

# %%
def total_unique_products_per_user():
    """
    Calculate how many unique products each user has purchased in total.
    """
    merged = order_products_denormalized.merge(orders[["order_id", "user_id"]], on="order_id")
    unique_products = (
        merged.groupby("user_id")["product_id"]
        .nunique()
        .reset_index()
        .rename(columns={"product_id": "unique_products_bought"})
    )
    return unique_products
#total_unique_products_per_user().head(1)
# Out:
#    user_id  unique_products_bought
# 0        3                      33

# %%
def unique_to_total_product_ratio_per_user():
    """
    Calculate the ratio of unique products bought to total products bought per user.
    This shows how diverse the user's purchases are relative to their total quantity.
    """
    total = total_products_per_user()
    unique = total_unique_products_per_user()
    
    merged = total.merge(unique, on="user_id")
    merged["unique_to_total_product_ratio"] = merged["unique_products_bought"] / merged["total_products_bought"]
    
    return merged[["user_id", "unique_to_total_product_ratio"]]
#unique_to_total_product_ratio_per_user().head(1)
# Out:
#    user_id  unique_to_total_product_ratio
# 0        3                          0.375

# %% [markdown]
# ### Feature engineering **ORDER**: new table per feature with columns: order_id, feature_name

# %%
def add_feature_order_contains_alcohol():
    # Step 1: Identify all order_ids that include alcohol products
    alcohol_orders = order_products_denormalized[
        order_products_denormalized["department"] == "alcohol"
    ][["order_id"]].drop_duplicates()
    
    # Step 2: Mark these orders with a True flag
    alcohol_orders["contains_alcohol"] = True

    # Step 3: Get all unique orders and join with the alcohol flag
    all_orders = orders[["order_id"]].drop_duplicates()
    result = all_orders.merge(alcohol_orders, on="order_id", how="left")

    # Step 4: Fill missing values (orders without alcohol) with False (0)
    result["contains_alcohol"] = result["contains_alcohol"].fillna(False).astype(int)

    return result.set_index("order_id")

#add_feature_order_contains_alcohol().head(1)

# %%
def add_feature_order_item_count():
    # Count how many products each order contains
    item_counts = (
        order_products_denormalized
        .groupby("order_id")["product_id"]
        .count()
        .reset_index()
        .rename(columns={"product_id": "item_count"})
    )
    return item_counts

#add_feature_order_item_count().head(1)

# %%
def add_feature_order_unique_departments_count():
    # Count distinct departments per order_id
    dept_counts = (
        order_products_denormalized
        .groupby("order_id")["department"]
        .nunique()
        .reset_index()
        .rename(columns={"department": "unique_departments_count"})
    )
    return dept_counts#.set_index("order_id")

#add_feature_order_unique_departments_count().head(1)

# %%
def add_feature_order_unique_aisles_count():
    # Count distinct aisles per order_id
    aisle_counts = (
        order_products_denormalized
        .groupby("order_id")["aisle"]
        .nunique()
        .reset_index()
        .rename(columns={"aisle": "unique_aisles_count"})
    )
    return aisle_counts
#add_feature_order_unique_aisles_count().head(1)
# Out:
#    order_id  unique_aisles_count
# 0         1                    6

# %%
def add_feature_order_unique_departments_ratio():
    """
    Calculate the ratio of unique departments to total items per order. \n
    This feature reflects how diverse an order is relative to its size.
    """
    total_items = add_feature_order_item_count()
    unique_depts = add_feature_order_unique_departments_count()

    # Merge on order_id
    merged = total_items.merge(unique_depts, on="order_id")

    # Calculate ratio
    merged["unique_departments_ratio"] = merged["unique_departments_count"] / merged["item_count"]

    return merged[["order_id", "unique_departments_ratio"]]
#add_feature_order_unique_departments_ratio().head(1)
# Out:
#    order_id  unique_departments_ratio
# 0         1                     0.375

# %%
def add_feature_order_unique_aisles_ratio():
    """
    Calculate the ratio of unique aisles to total items per order. \n
    This feature indicates the variety of product aisles in the order normalized by order size.
    """
    total_items = add_feature_order_item_count()
    unique_aisles = add_feature_order_unique_aisles_count()

    merged = total_items.merge(unique_aisles, on="order_id")

    merged["unique_aisles_ratio"] = merged["unique_aisles_count"] / merged["item_count"]

    return merged[["order_id", "unique_aisles_ratio"]]
#add_feature_order_unique_aisles_ratio().head(1)
# Out:
#    order_id  unique_aisles_ratio
# 0         1                 0.75

# %% [markdown]
# ### Feature engineering **ORDER** - **USER**: new table per feature with columns: order_id, feature_name

# %%
def add_cumulative_product_purchases_per_user():
    # 1. Merge orders und order_products_denormalized, damit wir user_id, product_id und order_date haben
    merged = order_products_denormalized.merge(
        orders[["order_id", "user_id", "order_date"]], on="order_id"
    )

    # 2. Sortiere nach user_id, product_id und order_date, damit der Zeitverlauf stimmt
    merged = merged.sort_values(by=["user_id", "product_id", "order_date"])

    # 3. Erstelle eine kumulative Zählung (cumcount) pro user_id und product_id
    #    cumcount zählt ab 0, also entspricht es, wie oft der User das Produkt vor der aktuellen Bestellung gekauft hat
    merged["times_product_bought_before"] = merged.groupby(
        ["user_id", "product_id"]
    ).cumcount()

    return merged
#add_cumulative_product_purchases_per_user().head(1)

# %%
def latest_tip_rate_per_user_product():
    """
    Return the latest purchase per user-product combination with the tip rate
    observed on *prior* purchases of that product by the user.
    If it's the first time, the value will be NaN.
    """
    merged = order_products_denormalized.merge(
        orders[["order_id", "user_id", "order_date"]], on="order_id"
    ).merge(
        tips_public[["order_id", "tip"]], on="order_id", how="left"
    )

    merged = merged.sort_values(by=["user_id", "product_id", "order_date"])

    merged["tip"] = merged["tip"].fillna(False).astype(float)

    # Count how often user bought the product before
    merged["times_product_bought_before"] = merged.groupby(
        ["user_id", "product_id"]
    ).cumcount()

    # How many of those times included a tip
    merged["tip_cumsum"] = merged.groupby(
        ["user_id", "product_id"]
    )["tip"].cumsum() - merged["tip"]

    merged["tip_rate_before"] = merged["tip_cumsum"] / merged["times_product_bought_before"]

    # Only keep the most recent row for each (user_id, product_id)
    latest = merged.sort_values(by="order_date").groupby(
        ["user_id", "product_id"], as_index=False
    ).last()

    return latest[["user_id", "product_id", "tip_rate_before"]]
#latest_tip_rate_per_user_product().head(6)

# %%
def add_avg_tip_rate_before_per_order():
    """
    For each order, calculate the average historical tip rate of all products
    in that order (based on user's previous purchases).
    This is useful as a predictive feature for whether a tip will be given.
    """
    # Merge all relevant info
    merged = order_products_denormalized.merge(
        orders[["order_id", "user_id", "order_date"]], on="order_id"
    ).merge(
        tips_public[["order_id", "tip"]], on="order_id", how="left"
    )

    merged = merged.sort_values(by=["user_id", "product_id", "order_date"])

    merged["tip"] = merged["tip"].fillna(0.0).astype(float)

    # Calculate how often user bought product before
    merged["times_product_bought_before"] = merged.groupby(
        ["user_id", "product_id"]
    ).cumcount()

    # How many of those had tips
    merged["tip_cumsum"] = merged.groupby(
        ["user_id", "product_id"]
    )["tip"].cumsum() - merged["tip"]

    merged["tip_rate_before"] = merged["tip_cumsum"] / merged["times_product_bought_before"]
    merged["tip_rate_before"] = merged["tip_rate_before"].replace([float("inf"), -float("inf")], pd.NA)

    # Now compute average per order (ignoring NaNs for first-time products)
    avg_tip_rate_per_order = merged.groupby("order_id")["tip_rate_before"].mean().reset_index()
    avg_tip_rate_per_order.columns = ["order_id", "avg_tip_rate_before"]

    return avg_tip_rate_per_order
avg_tip_rate_before_per_order = add_avg_tip_rate_before_per_order()
avg_tip_rate_before_per_order.head(1)

# %%
orders[orders["user_id"] == 5].merge(order_products_denormalized).merge(tips_public).merge(avg_tip_rate_before_per_order)
# Out:
#     order_id  user_id          order_date  product_id  add_to_cart_order  \
# 0    2717275        5 2024-04-02 12:01:12       15349                  1
# 1    2717275        5 2024-04-02 12:01:12       21413                  2
# 2    2717275        5 2024-04-02 12:01:12       48775                  3
# 3    2717275        5 2024-04-02 12:01:12       28289                  4
# 4    2717275        5 2024-04-02 12:01:12        8518                  5
# 5    2717275        5 2024-04-02 12:01:12       11777                  6
# 6    2717275        5 2024-04-02 12:01:12       31717                  7
# 7    2717275        5 2024-04-02 12:01:12       26604                  8
# 8    2717275        5 2024-04-02 12:01:12       43693                  9
# 9    2717275        5 2024-04-02 12:01:12       22475                 10
# 10   2717275        5 2024-04-02 12:01:12       24535                 11
# 11   1909121        5 2024-04-13 16:41:16       43693                  1
# 12   1909121        5 2024-04-13 16:41:16        6808                  2
# 13   1909121        5 2024-04-13 16:41:16       24535                  3
# 14   1909121        5 2024-04-13 16:41:16       11777                  4
# 15   1909121        5 2024-04-13 16:41:16       21616                  5
# 16   1909121        5 2024-04-13 16:41:16       18761                  6
# 17   1909121        5 2024-04-13 16:41:16       26604                  7
# 18   1909121        5 2024-04-13 16:41:16       13870                  8
# 19   1909121        5 2024-04-13 16:41:16       13988                  9
# 20   2267326        5 2024-04-23 18:01:02       26604                  1
# 21   2267326        5 2024-04-23 18:01:02       11777                  2
# 22   2267326        5 2024-04-23 18:01:02       20754                  3
# 23   2267326        5 2024-04-23 18:01:02       24231                  4
# 24   2267326        5 2024-04-23 18:01:02       40706                  5
# 25    157374        5 2024-05-12 18:34:15       27344                  1
# 26    157374        5 2024-05-12 18:34:15       24535                  2
# 27    157374        5 2024-05-12 18:34:15       43693                  3
# 28    157374        5 2024-05-12 18:34:15       40706                  4
# 29    157374        5 2024-05-12 18:34:15       16168                  5
# 30    157374        5 2024-05-12 18:34:15       21413                  6
# 31    157374        5 2024-05-12 18:34:15       13988                  7
# 32    157374        5 2024-05-12 18:34:15        3376                  8
# 33    157374        5 2024-05-12 18:34:15        8518                  9
# 34    157374        5 2024-05-12 18:34:15       26604                 10
# 35    157374        5 2024-05-12 18:34:15       11777                 11
# 36    157374        5 2024-05-12 18:34:15        5999                 12
#
#                                      product_name  aisle_id  department_id  \
# 0                        Organic Raw Agave Nectar        29             13
# 1                                    Organic Soba        66              6
# 2                             Organic Red Cabbage        83              4
# 3                        Organic Shredded Carrots       123              4
# 4                               Organic Red Onion        83              4
# 5                                 Red Raspberries       123              4
# 6                                Organic Cilantro        16              4
# 7                            Organic Blackberries        24              4
# 8                            Whole Vitamin D Milk        84             16
# 9                                          Jicama        83              4
# 10                        Plain Whole Milk Yogurt       120             16
# 11                           Whole Vitamin D Milk        84             16
# 12            Organic Spinach & Cheese Tortellini        12              9
# 13                        Plain Whole Milk Yogurt       120             16
# 14                                Red Raspberries       123              4
# 15                           Organic Baby Arugula       123              4
# 16                     Balsamic Vinegar Of Modena        19             13
# 17                           Organic Blackberries        24              4
# 18           Lightly Salted Baked Snap Pea Crisps       107             19
# 19                                      Snow Peas        83              4
# 20                           Organic Blackberries        24              4
# 21                                Red Raspberries       123              4
# 22                      Mediterranean Mint Gelato        37              1
# 23                   Tahitian Vanilla Bean Gelato        37              1
# 24                         Organic Grape Tomatoes       123              4
# 25                           Uncured Genoa Salami        96             20
# 26                        Plain Whole Milk Yogurt       120             16
# 27                           Whole Vitamin D Milk        84             16
# 28                         Organic Grape Tomatoes       123              4
# 29                Large Organic Omega3 Brown Eggs        86             16
# 30                                   Organic Soba        66              6
# 31                                      Snow Peas        83              4
# 32  Organic Whole Kernel Sweet Corn No Salt Added        81             15
# 33                              Organic Red Onion        83              4
# 34                           Organic Blackberries        24              4
# 35                                Red Raspberries       123              4
# 36                      Semi-Soft Cheese, Ripened        21             16
#
#          department                       aisle    tip  avg_tip_rate_before
# 0            pantry       honeys syrups nectars  False                  NaN
# 1     international                 asian foods  False                  NaN
# 2           produce            fresh vegetables  False                  NaN
# 3           produce  packaged vegetables fruits  False                  NaN
# 4           produce            fresh vegetables  False                  NaN
# 5           produce  packaged vegetables fruits  False                  NaN
# 6           produce                 fresh herbs  False                  NaN
# 7           produce                fresh fruits  False                  NaN
# 8        dairy eggs                        milk  False                  NaN
# 9           produce            fresh vegetables  False                  NaN
# 10       dairy eggs                      yogurt  False                  NaN
# 11       dairy eggs                        milk   True             0.000000
# 12  dry goods pasta                 fresh pasta   True             0.000000
# 13       dairy eggs                      yogurt   True             0.000000
# 14          produce  packaged vegetables fruits   True             0.000000
# 15          produce  packaged vegetables fruits   True             0.000000
# 16           pantry               oils vinegars   True             0.000000
# 17          produce                fresh fruits   True             0.000000
# 18           snacks              chips pretzels   True             0.000000
# 19          produce            fresh vegetables   True             0.000000
# 20          produce                fresh fruits  False             0.500000
# 21          produce  packaged vegetables fruits  False             0.500000
# 22           frozen               ice cream ice  False             0.500000
# 23           frozen               ice cream ice  False             0.500000
# 24          produce  packaged vegetables fruits  False             0.500000
# 25             deli                  lunch meat   True             0.333333
# 26       dairy eggs                      yogurt   True             0.333333
# 27       dairy eggs                        milk   True             0.333333
# 28          produce  packaged vegetables fruits   True             0.333333
# 29       dairy eggs                        eggs   True             0.333333
# 30    international                 asian foods   True             0.333333
# 31          produce            fresh vegetables   True             0.333333
# 32     canned goods    canned jarred vegetables   True             0.333333
# 33          produce            fresh vegetables   True             0.333333
# 34          produce                fresh fruits   True             0.333333
# 35          produce  packaged vegetables fruits   True             0.333333
# 36       dairy eggs             packaged cheese   True             0.333333

# %%
def add_avg_tip_rate_before_per_product_row():
    """
    Add a column to each order-product row that contains the average historical tip rate
    the user had given for this specific product in the past. If the product is new, it's NaN.
    Useful as a contextual feature for tipping behavior on a product level.
    """
    # 1. Merge necessary data
    merged = order_products_denormalized.merge(
        orders[["order_id", "user_id", "order_date"]], on="order_id"
    ).merge(
        tips_public[["order_id", "tip"]], on="order_id", how="left"
    )

    # 2. Sort to ensure chronological order for cumsum logic
    merged = merged.sort_values(by=["user_id", "product_id", "order_date"])

    # 3. Ensure tip is numeric
    merged["tip"] = merged["tip"].fillna(0.0).astype(float)

    # 4. Count how many times the user has bought this product before this order
    merged["times_product_bought_before"] = merged.groupby(
        ["user_id", "product_id"]
    ).cumcount()

    # 5. Cumulative sum of tips before this point
    merged["tip_cumsum"] = merged.groupby(["user_id", "product_id"])["tip"].cumsum() - merged["tip"]

    # 6. Compute historical tip rate before for this product
    merged["avg_tip_rate_before_product"] = (
        merged["tip_cumsum"] / merged["times_product_bought_before"]
    )

    # 7. Handle division by 0 (new products)
    merged["avg_tip_rate_before_product"] = merged["avg_tip_rate_before_product"].replace(
        [float("inf"), -float("inf")], pd.NA
    )

    return merged
add_avg_tip_rate_before_per_product_row().sort_values("order_date").head(60)
# Out:
#           order_id  product_id  add_to_cart_order  \
# 6792069    1510472       10121                  9
# 6792063    1510472       12745                  3
# 6792066    1510472       14161                  6
# 6792075    1510472       15741                 15
# 6792062    1510472       19348                  2
# 6792065    1510472       24852                  5
# 6792074    1510472       28945                 14
# 6792071    1510472       29987                 11
# 6792073    1510472       22256                 13
# 6792067    1510472       33787                  7
# 6792068    1510472       33754                  8
# 6792070    1510472       48783                 10
# 6792061    1510472       47766                  1
# 6792072    1510472       49267                 12
# 6792064    1510472       42828                  4
# 6792076    1510472       46853                 16
# 11846164   2707022       39993                 10
# 11846165   2707022        3323                 11
# 11846176   2707022       40910                 22
# 11846166   2707022       38049                 12
# 11846156   2707022       37763                  2
# 11846162   2707022       37564                  8
# 11846175   2707022       36393                 21
# 11846174   2707022        1006                 20
# 11846160   2707022        1511                  6
# 11846170   2707022       36307                 16
# 11846158   2707022       45064                  4
# 11846177   2707022       35406                 23
# 11846157   2707022       32915                  3
# 11846155   2707022       31564                  1
# 11846163   2707022       28993                  9
# 11846161   2707022       25509                  7
# 11846169   2707022       23734                 15
# 11846180   2707022       44949                 26
# 11846168   2707022       22952                 14
# 11846179   2707022       12513                 25
# 11846178   2707022        6631                 24
# 11846171   2707022       45009                 17
# 11846172   2707022       12140                 18
# 11846167   2707022       49222                 13
# 11846173   2707022       46842                 19
# 11846159   2707022        7806                  5
# 7973962    1789128       11154                  5
# 7973960    1789128       43263                  3
# 7973969    1789128       42888                 12
# 7973961    1789128       41728                  4
# 7973964    1789128       30006                  7
# 7973965    1789128       21795                  8
# 7973968    1789128       25824                 11
# 7973958    1789128       13866                  1
# 7973966    1789128       13525                  9
# 7973967    1789128        1578                 10
# 7973963    1789128        9695                  6
# 7973959    1789128       19495                  2
# 10320468   2345092       22802                  1
# 9971079    2262337       28226                  1
# 9971082    2262337        4920                  4
# 9971080    2262337       42768                  2
# 9971083    2262337        9076                  5
# 9971081    2262337       27156                  3
#
#                                                product_name  aisle_id  \
# 6792069                                 Wild Sockeye Salmon        15
# 6792063                          Yogurt, Lowfat, Strawberry       120
# 6792066                                                Kiwi        24
# 6792075                       Strawberry C Monster Smoothie        31
# 6792062                                       Fat Free Milk        84
# 6792065                                              Banana        24
# 6792074   Honey Lemon with Echinacea Cough Suppressant T...        11
# 6792071                                 Shredded Mozzarella        21
# 6792073                          Organic Throat Comfort Tea        94
# 6792067    Total 2% Lowfat Greek Strained Yogurt with Peach       120
# 6792068   Total 2% with Strawberry Lowfat Greek Strained...       120
# 6792070                           Hydroponic Boston Lettuce       123
# 6792061                                     Organic Avocado        24
# 6792072                          Vegetable Broth Low Sodium        69
# 6792064                                Whipped Cream Cheese       108
# 6792076   Power C Machine All Natural Fruit + Boost Juic...        31
# 11846164                                 Vine Ripe Tomatoes        83
# 11846165                    Classic Catalina Dressing & Dip        89
# 11846176                                          Root Beer        77
# 11846166                       Crispy Rounds Tortilla Chips       107
# 11846156                 Disinfectant Cleanser, with Bleach       114
# 11846162                 Hardwood Smoked Lower Sodium Bacon       106
# 11846175                            Eggo Buttermilk Waffles        52
# 11846174                          Philadelphia Cream Cheese       108
# 11846160        2% Reduced Fat DHA Omega-3 Reduced Fat Milk        84
# 11846170                    Milano Double Chocolate Cookies        61
# 11846158                                  Honey Wheat Bread       112
# 11846177                      All Natural Peach Tea Bottles        94
# 11846157                                       Honey Turkey        96
# 11846155                                           Crackers        78
# 11846163                                    Iceberg Lettuce        83
# 11846161                             Medium Flour Tortillas       128
# 11846169                                         Sour Cream       108
# 11846180               Organic Lowfat French Vanilla Yogurt       120
# 11846168                                     Farfalle Pasta       131
# 11846179      Light Strawberries 'n Bananas Fat Free Yogurt       120
# 11846178      No Pulp Calcium & Vitamin D Pure Orange Juice        31
# 11846171                 Chocolate Chocolate Chip Ice Cream        37
# 11846172                                          Diet Soda        77
# 11846167               Sun-Dried Tomato Alfredo Pasta Sauce         9
# 11846173                            Plain Pre-Sliced Bagels        93
# 11846159                           Soft Pretzel Burger Buns        43
# 7973962                                    Corn Pops Cereal       121
# 7973960                  Crunchy Oats N' Honey Granola Bars         3
# 7973969   Cheese Sticks, Variety Pack, Colby Jack & Cheddar        21
# 7973961            Wheat Thins Multipack Variety 12 Ct 12oz        78
# 7973964                  Ritz Cheese Cracker Sandwich Packs        78
# 7973965                   Extra Virgin Olive Oil Rich Taste        19
# 7973968                             Pita Chips Simply Naked       107
# 7973958                                 Deluxe Plain Bagels        93
# 7973966                                    Balsamic Vinegar        19
# 7973967                                  Apple Jacks Cereal       121
# 7973963          Goldfish Baked Snack Crackers Variety Pack        78
# 7973959                           Variety Pack Snack Stacks       107
# 10320468                                      Mineral Water       115
# 9971079                           Power Grains Waffles 6 ct        52
# 9971082                                 Seedless Red Grapes       123
# 9971080                              Organic Garbanzo Beans        59
# 9971083                                         Blueberries       116
# 9971081                                 Organic Black Beans        59
#
#           department_id       department                          aisle  \
# 6792069              12     meat seafood               packaged seafood
# 6792063              16       dairy eggs                         yogurt
# 6792066               4          produce                   fresh fruits
# 6792075               7        beverages                   refrigerated
# 6792062              16       dairy eggs                           milk
# 6792065               4          produce                   fresh fruits
# 6792074              11    personal care               cold flu allergy
# 6792071              16       dairy eggs                packaged cheese
# 6792073               7        beverages                            tea
# 6792067              16       dairy eggs                         yogurt
# 6792068              16       dairy eggs                         yogurt
# 6792070               4          produce     packaged vegetables fruits
# 6792061               4          produce                   fresh fruits
# 6792072              15     canned goods            soup broth bouillon
# 6792064              16       dairy eggs           other creams cheeses
# 6792076               7        beverages                   refrigerated
# 11846164              4          produce               fresh vegetables
# 11846165             13           pantry        salad dressing toppings
# 11846176              7        beverages                    soft drinks
# 11846166             19           snacks                 chips pretzels
# 11846156             17        household              cleaning products
# 11846162             12     meat seafood         hot dogs bacon sausage
# 11846175              1           frozen               frozen breakfast
# 11846174             16       dairy eggs           other creams cheeses
# 11846160             16       dairy eggs                           milk
# 11846170             19           snacks                  cookies cakes
# 11846158              3           bakery                          bread
# 11846177              7        beverages                            tea
# 11846157             20             deli                     lunch meat
# 11846155             19           snacks                       crackers
# 11846163              4          produce               fresh vegetables
# 11846161              3           bakery           tortillas flat bread
# 11846169             16       dairy eggs           other creams cheeses
# 11846180             16       dairy eggs                         yogurt
# 11846168              9  dry goods pasta                      dry pasta
# 11846179             16       dairy eggs                         yogurt
# 11846178              7        beverages                   refrigerated
# 11846171              1           frozen                  ice cream ice
# 11846172              7        beverages                    soft drinks
# 11846167              9  dry goods pasta                    pasta sauce
# 11846173              3           bakery               breakfast bakery
# 11846159              3           bakery                     buns rolls
# 7973962              14        breakfast                         cereal
# 7973960              19           snacks            energy granola bars
# 7973969              16       dairy eggs                packaged cheese
# 7973961              19           snacks                       crackers
# 7973964              19           snacks                       crackers
# 7973965              13           pantry                  oils vinegars
# 7973968              19           snacks                 chips pretzels
# 7973958               3           bakery               breakfast bakery
# 7973966              13           pantry                  oils vinegars
# 7973967              14        breakfast                         cereal
# 7973963              19           snacks                       crackers
# 7973959              19           snacks                 chips pretzels
# 10320468              7        beverages  water seltzer sparkling water
# 9971079               1           frozen               frozen breakfast
# 9971082               4          produce     packaged vegetables fruits
# 9971080              15     canned goods             canned meals beans
# 9971083               1           frozen                 frozen produce
# 9971081              15     canned goods             canned meals beans
#
#           user_id          order_date  tip  times_product_bought_before  \
# 6792069     87063 2024-01-17 00:17:26  1.0                            0
# 6792063     87063 2024-01-17 00:17:26  1.0                            0
# 6792066     87063 2024-01-17 00:17:26  1.0                            0
# 6792075     87063 2024-01-17 00:17:26  1.0                            0
# 6792062     87063 2024-01-17 00:17:26  1.0                            0
# 6792065     87063 2024-01-17 00:17:26  1.0                            0
# 6792074     87063 2024-01-17 00:17:26  1.0                            0
# 6792071     87063 2024-01-17 00:17:26  1.0                            0
# 6792073     87063 2024-01-17 00:17:26  1.0                            0
# 6792067     87063 2024-01-17 00:17:26  1.0                            0
# 6792068     87063 2024-01-17 00:17:26  1.0                            0
# 6792070     87063 2024-01-17 00:17:26  1.0                            0
# 6792061     87063 2024-01-17 00:17:26  1.0                            0
# 6792072     87063 2024-01-17 00:17:26  1.0                            0
# 6792064     87063 2024-01-17 00:17:26  1.0                            0
# 6792076     87063 2024-01-17 00:17:26  1.0                            0
# 11846164    22717 2024-01-17 00:24:45  0.0                            0
# 11846165    22717 2024-01-17 00:24:45  0.0                            0
# 11846176    22717 2024-01-17 00:24:45  0.0                            0
# 11846166    22717 2024-01-17 00:24:45  0.0                            0
# 11846156    22717 2024-01-17 00:24:45  0.0                            0
# 11846162    22717 2024-01-17 00:24:45  0.0                            0
# 11846175    22717 2024-01-17 00:24:45  0.0                            0
# 11846174    22717 2024-01-17 00:24:45  0.0                            0
# 11846160    22717 2024-01-17 00:24:45  0.0                            0
# 11846170    22717 2024-01-17 00:24:45  0.0                            0
# 11846158    22717 2024-01-17 00:24:45  0.0                            0
# 11846177    22717 2024-01-17 00:24:45  0.0                            0
# 11846157    22717 2024-01-17 00:24:45  0.0                            0
# 11846155    22717 2024-01-17 00:24:45  0.0                            0
# 11846163    22717 2024-01-17 00:24:45  0.0                            0
# 11846161    22717 2024-01-17 00:24:45  0.0                            0
# 11846169    22717 2024-01-17 00:24:45  0.0                            0
# 11846180    22717 2024-01-17 00:24:45  0.0                            0
# 11846168    22717 2024-01-17 00:24:45  0.0                            0
# 11846179    22717 2024-01-17 00:24:45  0.0                            0
# 11846178    22717 2024-01-17 00:24:45  0.0                            0
# 11846171    22717 2024-01-17 00:24:45  0.0                            0
# 11846172    22717 2024-01-17 00:24:45  0.0                            0
# 11846167    22717 2024-01-17 00:24:45  0.0                            0
# 11846173    22717 2024-01-17 00:24:45  0.0                            0
# 11846159    22717 2024-01-17 00:24:45  0.0                            0
# 7973962    125953 2024-01-17 06:42:03  0.0                            0
# 7973960    125953 2024-01-17 06:42:03  0.0                            0
# 7973969    125953 2024-01-17 06:42:03  0.0                            0
# 7973961    125953 2024-01-17 06:42:03  0.0                            0
# 7973964    125953 2024-01-17 06:42:03  0.0                            0
# 7973965    125953 2024-01-17 06:42:03  0.0                            0
# 7973968    125953 2024-01-17 06:42:03  0.0                            0
# 7973958    125953 2024-01-17 06:42:03  0.0                            0
# 7973966    125953 2024-01-17 06:42:03  0.0                            0
# 7973967    125953 2024-01-17 06:42:03  0.0                            0
# 7973963    125953 2024-01-17 06:42:03  0.0                            0
# 7973959    125953 2024-01-17 06:42:03  0.0                            0
# 10320468    57110 2024-01-17 08:08:49  0.0                            0
# 9971079    189818 2024-01-17 08:12:16  0.0                            0
# 9971082    189818 2024-01-17 08:12:16  0.0                            0
# 9971080    189818 2024-01-17 08:12:16  0.0                            0
# 9971083    189818 2024-01-17 08:12:16  0.0                            0
# 9971081    189818 2024-01-17 08:12:16  0.0                            0
#
#           tip_cumsum  avg_tip_rate_before_product
# 6792069          0.0                          NaN
# 6792063          0.0                          NaN
# 6792066          0.0                          NaN
# 6792075          0.0                          NaN
# 6792062          0.0                          NaN
# 6792065          0.0                          NaN
# 6792074          0.0                          NaN
# 6792071          0.0                          NaN
# 6792073          0.0                          NaN
# 6792067          0.0                          NaN
# 6792068          0.0                          NaN
# 6792070          0.0                          NaN
# 6792061          0.0                          NaN
# 6792072          0.0                          NaN
# 6792064          0.0                          NaN
# 6792076          0.0                          NaN
# 11846164         0.0                          NaN
# 11846165         0.0                          NaN
# 11846176         0.0                          NaN
# 11846166         0.0                          NaN
# 11846156         0.0                          NaN
# 11846162         0.0                          NaN
# 11846175         0.0                          NaN
# 11846174         0.0                          NaN
# 11846160         0.0                          NaN
# 11846170         0.0                          NaN
# 11846158         0.0                          NaN
# 11846177         0.0                          NaN
# 11846157         0.0                          NaN
# 11846155         0.0                          NaN
# 11846163         0.0                          NaN
# 11846161         0.0                          NaN
# 11846169         0.0                          NaN
# 11846180         0.0                          NaN
# 11846168         0.0                          NaN
# 11846179         0.0                          NaN
# 11846178         0.0                          NaN
# 11846171         0.0                          NaN
# 11846172         0.0                          NaN
# 11846167         0.0                          NaN
# 11846173         0.0                          NaN
# 11846159         0.0                          NaN
# 7973962          0.0                          NaN
# 7973960          0.0                          NaN
# 7973969          0.0                          NaN
# 7973961          0.0                          NaN
# 7973964          0.0                          NaN
# 7973965          0.0                          NaN
# 7973968          0.0                          NaN
# 7973958          0.0                          NaN
# 7973966          0.0                          NaN
# 7973967          0.0                          NaN
# 7973963          0.0                          NaN
# 7973959          0.0                          NaN
# 10320468         0.0                          NaN
# 9971079          0.0                          NaN
# 9971082          0.0                          NaN
# 9971080          0.0                          NaN
# 9971083          0.0                          NaN
# 9971081          0.0                          NaN
